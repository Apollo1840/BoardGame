# %%
import pandas as pd
import json
import ast
import uuid
from datetime import datetime

today_str = datetime.now().strftime('%Y%m%d')

def make_card_id(idx):
    return f"{today_str}-{idx:05d}-" + str(uuid.uuid4())[:8]

def remove_empty_columns(df):
    # Remove columns where the column name is empty or only whitespace
    cols_to_keep = [col for col in df.columns if str(col).strip() != '' and not str(col).strip().startswith('Unnamed')]
    return df[cols_to_keep]

def remove_card_id_column(df):
    if 'card_id' in df.columns:
        df = df.drop(columns=['card_id'])
    return df

def append_card_id_column(df, start_idx=1):
    if 'card_id' not in df.columns:
        df.insert(0, 'card_id', [make_card_id(i+start_idx) for i in range(len(df))])
    return df

def append_last_update_datetime_column(df):
    if 'last_update_datetime' not in df.columns:
        df['last_update_datetime'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    return df

# %%
df = pd.read_csv(
    'monster_cards.csv',
    sep='|',
    encoding='utf-8',
    converters={
        'attributes': lambda x: ast.literal_eval(x) if x and x != '{}' else {},
        'skills': lambda x: ast.literal_eval(x) if x and x != '[]' else []
    }
)

# %%
df.head()
# Out:
#   Unnamed: 0 card_title  level monster_type                     description  \
# 0        NaN      斯巴达武士      0            土    【人类种】在这个充满怪物的基姆世界，人类也是怪物的一种。
# 1        NaN        狼巨人      1            木  【兽人种】栖息在巨木林的巨大的狼人，最大的身高可以到20米。
# 2        NaN        石砖人      2            岩              【石头人种】废弃的城堡变化成的石头人
# 3        NaN      大嘴哥布林      1          NaN      【兽人种】抢夺了族人的食物而长大的哥布林，寿命很短。
# 4        NaN      刺客哥布林      0            金        【兽人种】虽然但是，在大白天会不会太显眼了一点。
#
#    attack  defence  magic                                         attributes  \
# 0       5        5    0.0                                                 {}
# 1       7        6    0.0  {'responsive_attribute': '被翻面召唤时，可以立即攻击己方场上一只怪...
# 2      10       10    0.0                                                 {}
# 3       7        3    0.0                                                 {}
# 4       2        0    0.0  {'normal_attribute': '当我方场上有其他怪兽时，无法指定为被攻击的对象。...
#
#                                               skills  \
# 0  [{'name': '背水一击', 'energy_cost': 1, 'effect': ...
# 1  [{'name': '狼嗥', 'energy_cost': 0, 'effect': '可...
# 2                                                 []
# 3  [{'name': '召唤', 'energy_cost': 0, 'effect': '特...
# 4                                                 []
#
#                           image Unnamed: 11
# 0  pictures/spartan_samurai.png         NaN
# 1       pictures/wolf_gaint.png         NaN
# 2       pictures/castle_man.png         NaN
# 3       pictures/big_goblin.png         NaN
# 4  pictures/assassin_goblin.png         NaN

# %%
df = remove_empty_columns(df)
df.head()
# Out:
#                    card_id card_title  level monster_type  \
# 0  20250914-00001-aac543cf      斯巴达武士      0            土
# 1  20250914-00002-9e3bd879        狼巨人      1            木
# 2  20250914-00003-5bc46cc2        石砖人      2            岩
# 3  20250914-00004-7622517c      大嘴哥布林      1          NaN
# 4  20250914-00005-cf217e76      刺客哥布林      0            金
#
#                       description  attack  defence  magic  \
# 0    【人类种】在这个充满怪物的基姆世界，人类也是怪物的一种。       5        5    0.0
# 1  【兽人种】栖息在巨木林的巨大的狼人，最大的身高可以到20米。       7        6    0.0
# 2              【石头人种】废弃的城堡变化成的石头人      10       10    0.0
# 3      【兽人种】抢夺了族人的食物而长大的哥布林，寿命很短。       7        3    0.0
# 4        【兽人种】虽然但是，在大白天会不会太显眼了一点。       2        0    0.0
#
#                                           attributes  \
# 0                                                 {}
# 1  {'responsive_attribute': '被翻面召唤时，可以立即攻击己方场上一只怪...
# 2                                                 {}
# 3                                                 {}
# 4  {'normal_attribute': '当我方场上有其他怪兽时，无法指定为被攻击的对象。...
#
#                                               skills  \
# 0  [{'name': '背水一击', 'energy_cost': 1, 'effect': ...
# 1  [{'name': '狼嗥', 'energy_cost': 0, 'effect': '可...
# 2                                                 []
# 3  [{'name': '召唤', 'energy_cost': 0, 'effect': '特...
# 4                                                 []
#
#                           image last_update_datetime
# 0  pictures/spartan_samurai.png  2025-09-14 07:59:20
# 1       pictures/wolf_gaint.png  2025-09-14 07:59:20
# 2       pictures/castle_man.png  2025-09-14 07:59:20
# 3       pictures/big_goblin.png  2025-09-14 07:59:20
# 4  pictures/assassin_goblin.png  2025-09-14 07:59:20

# %%
df = append_card_id_column(df)
df = append_last_update_datetime_column(df)

# %%
df.to_csv('monster_cards.csv', sep='|', index=False, encoding='utf-8')
df.head()
# Out:
#                    card_id card_title  level monster_type  \
# 0  20250914-00001-aac543cf      斯巴达武士      0            土
# 1  20250914-00002-9e3bd879        狼巨人      1            木
# 2  20250914-00003-5bc46cc2        石砖人      2            岩
# 3  20250914-00004-7622517c      大嘴哥布林      1          NaN
# 4  20250914-00005-cf217e76      刺客哥布林      0            金
#
#                       description  attack  defence  magic  \
# 0    【人类种】在这个充满怪物的基姆世界，人类也是怪物的一种。       5        5    0.0
# 1  【兽人种】栖息在巨木林的巨大的狼人，最大的身高可以到20米。       7        6    0.0
# 2              【石头人种】废弃的城堡变化成的石头人      10       10    0.0
# 3      【兽人种】抢夺了族人的食物而长大的哥布林，寿命很短。       7        3    0.0
# 4        【兽人种】虽然但是，在大白天会不会太显眼了一点。       2        0    0.0
#
#                                           attributes  \
# 0                                                 {}
# 1  {'responsive_attribute': '被翻面召唤时，可以立即攻击己方场上一只怪...
# 2                                                 {}
# 3                                                 {}
# 4  {'normal_attribute': '当我方场上有其他怪兽时，无法指定为被攻击的对象。...
#
#                                               skills  \
# 0  [{'name': '背水一击', 'energy_cost': 1, 'effect': ...
# 1  [{'name': '狼嗥', 'energy_cost': 0, 'effect': '可...
# 2                                                 []
# 3  [{'name': '召唤', 'energy_cost': 0, 'effect': '特...
# 4                                                 []
#
#                           image last_update_datetime
# 0  pictures/spartan_samurai.png  2025-09-14 07:59:20
# 1       pictures/wolf_gaint.png  2025-09-14 07:59:20
# 2       pictures/castle_man.png  2025-09-14 07:59:20
# 3       pictures/big_goblin.png  2025-09-14 07:59:20
# 4  pictures/assassin_goblin.png  2025-09-14 07:59:20

# %%
# Read prophecy_cards.csv and add card_id, last_update_datetime, and effect columns
df_prophecy = pd.read_csv(
    'prophecy_cards_en.csv',
    sep='|',
    encoding='utf-8'
)

# %%
# Start card_id from after the last monster card
df_prophecy = append_card_id_column(df_prophecy, start_idx=len(df)+1)
df_prophecy = append_last_update_datetime_column(df_prophecy)
df_prophecy.head()

# %%
df_prophecy.to_csv('prophecy_cards_en.csv', sep='|', index=False, encoding='utf-8')
df_prophecy.head()
# Out:
#                    card_id             card_title  \
# 0  20250913-00084-aee4a20e             Fool’s Axe
# 1  20250913-00085-4f160f39  River God’s Sacrifice
# 2  20250913-00086-156d13e9         Fearless Siege
# 3  20250913-00087-8017584b     Aggregation Effect
# 4  20250913-00088-3c91693e           Raging Party
#
#                                         introduction  \
# 0  [Continuous/Equip] Guided by the Seer, people ...
# 1  The Seer said some must be offered for prosper...
# 2      The Seer said: “All in—what’s there to fear?”
# 3                                                NaN
# 4                                                NaN
#
#                                               effect responsive_effect  \
# 0  Negate the equipped monster’s attributes; it c...               NaN
# 1          Destroy 1 of your monsters; draw 3 cards.               NaN
# 2  All of your monsters that can attack perform o...               NaN
# 3  If you control a monster, you may perform two ...               NaN
# 4  All your monsters get ATK + (your number of mo...               NaN
#
#                     image last_update_datetime
# 0   pictures/fool_arc.png  2025-09-13 21:21:52
# 1  pictures/sacrifice.png  2025-09-13 21:21:52
# 2      pictures/siege.png  2025-09-13 21:21:52
# 3   pictures/follower.png  2025-09-13 21:21:52
# 4    pictures/outrage.png  2025-09-13 21:21:52
